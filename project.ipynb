# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/archive (8).zip')

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.describe()
# Out:
#               year  selling_price     km_driven  mileage(km/ltr/kg)  \
# count  8128.000000   8.128000e+03  8.128000e+03         7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04           19.418783
# std       4.044249   8.062534e+05  5.655055e+04            4.037145
# min    1983.000000   2.999900e+04  1.000000e+00            0.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04           16.780000
# 50%    2015.000000   4.500000e+05  6.000000e+04           19.300000
# 75%    2017.000000   6.750000e+05  9.800000e+04           22.320000
# max    2020.000000   1.000000e+07  2.360457e+06           42.000000
#
#             engine        seats
# count  7907.000000  7907.000000
# mean   1458.625016     5.416719
# std     503.916303     0.959588
# min     624.000000     2.000000
# 25%    1197.000000     5.000000
# 50%    1248.000000     5.000000
# 75%    1582.000000     5.000000
# max    3604.000000    14.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                8128 non-null   object
#  1   year                8128 non-null   int64
#  2   selling_price       8128 non-null   int64
#  3   km_driven           8128 non-null   int64
#  4   fuel                8128 non-null   object
#  5   seller_type         8128 non-null   object
#  6   transmission        8128 non-null   object
#  7   owner               8128 non-null   object
#  8   mileage(km/ltr/kg)  7907 non-null   float64
#  9   engine              7907 non-null   float64
#  10  max_power           7913 non-null   object
#  11  seats               7907 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 762.1+ KB

# %%
df.isna().sum()
# Out:
# name                    0
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    221
# engine                221
# max_power             215
# seats                 221
# dtype: int64

# %%
import seaborn as sns
sns.barplot(x='year',y='mileage(km/ltr/kg)',data=df)
plt.title('mileage vs year')
plt.show()

# %%
sns.lineplot(x='fuel',y='engine',data=df,hue='year')
plt.title('fuel vs engine')
plt.show()

# %%
df.dtypes
# Out:
# name                   object
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                   object
# seller_type            object
# transmission           object
# owner                  object
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power              object
# seats                 float64
# dtype: object

# %%
df.shape
# Out:
# (8128, 12)

# %%
df1=df.head(5001)

# %%
df1
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1      Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2          Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3         Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                             ...   ...            ...        ...     ...
# 4996  Mahindra Logan Petrol 1.4 GLE  2010         200000     120000  Petrol
# 4997    Maruti Ciaz VDi Option SHVS  2016         700000      70000  Diesel
# 4998            Toyota Qualis FS B3  2002         229999     290000  Diesel
# 4999            Honda Accord 2.4 MT  2010         300000      74000  Petrol
# 5000         Honda Mobilio S i DTEC  2015         670000     120000  Diesel
#
# ...

# %%
column_values = df1["name"].values
column_values_list = df1["name"].tolist()

print(column_values)
print(column_values_list)
# Out:
# ['Maruti Swift Dzire VDI' 'Skoda Rapid 1.5 TDI Ambition'
#  'Honda City 2017-2020 EXi' ... 'Toyota Qualis FS B3'
#  'Honda Accord 2.4 MT' 'Honda Mobilio S i DTEC']
# ...

# %%
value_counts = df["name"].value_counts()
print(value_counts)
# Out:
# name
# Maruti Swift Dzire VDI                             129
# Maruti Alto 800 LXI                                 82
# Maruti Alto LXi                                     71
# BMW X4 M Sport X xDrive20d                          62
# Maruti Swift VDI                                    61
#                                                   ...
# Skoda Fabia 1.4 TDI Ambiente                         1
# Mahindra Scorpio VLX 2WD AT BSIII                    1
# Renault KWID Climber 1.0 AMT                         1
# Mahindra XUV300 W8 Option Dual Tone Diesel BSIV      1
# Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV         1
# Name: count, Length: 2058, dtype: int64

# %%
car_counts_dict = df["name"].value_counts().to_dict()
print(car_counts_dict)
# Out:
# {'Maruti Swift Dzire VDI': 129, 'Maruti Alto 800 LXI': 82, 'Maruti Alto LXi': 71, 'BMW X4 M Sport X xDrive20d': 62, 'Maruti Swift VDI': 61, 'Maruti Swift VDI BSIV': 59, 'Maruti Wagon R LXI': 53, 'Maruti Alto K10 VXI': 50, 'Hyundai EON Era Plus': 48, 'Maruti Wagon R VXI BS IV': 45, 'Maruti Ertiga VDI': 45, 'Maruti Alto LX': 44, 'Toyota Innova 2.5 VX (Diesel) 7 Seater': 44, 'Maruti Ritz VDi': 42, 'Maruti Swift Dzire VXI': 38, 'Tata Safari Storme EX': 38, 'Maruti 800 AC': 38, 'Maruti Baleno Alpha 1.3': 37, 'Hyundai Grand i10 1.2 CRDi Sportz': 34, 'Lexus ES 300h': 34, 'Jaguar XF 2.0 Diesel Portfolio': 34, 'Toyota Camry 2.5 Hybrid': 33, 'Renault KWID RXT': 33, 'Maruti Swift Dzire VDi': 33, 'Toyota Etios VX': 33, 'Skoda Rapid 1.6 MPI AT Elegance': 32, 'Honda Jazz VX': 32, 'Hyundai EON Magna Plus': 32, 'Maruti Alto K10 2010-2014 VXI': 32, 'Hyundai Verna 1.6 SX': 31, 'Maruti Swift AMT ZXI': 31, 'Honda Amaze V CVT Petrol BSIV': 31, 'Jaguar XE 2016-2019 2.0L Diesel Prestige': 30, 'Ford Figo Di
# ...

# %%
df["brand"] = df["name"].apply(lambda x: x.split(" ")[0])  # Get first word (brand)
print(df[["name", "brand"]].head())
# Out:
#                            name    brand
# 0        Maruti Swift Dzire VDI   Maruti
# 1  Skoda Rapid 1.5 TDI Ambition    Skoda
# 2      Honda City 2017-2020 EXi    Honda
# 3     Hyundai i20 Sportz Diesel  Hyundai
# 4        Maruti Swift VXI BSIII   Maruti

# %%
unique_brands = df["brand"].unique()
print(unique_brands)
# Out:
# ['Maruti' 'Skoda' 'Honda' 'Hyundai' 'Toyota' 'Ford' 'Renault' 'Mahindra'
#  'Tata' 'Chevrolet' 'Fiat' 'Datsun' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Audi' 'Volkswagen' 'BMW' 'Nissan' 'Lexus' 'Jaguar' 'Land' 'MG' 'Volvo'
#  'Daewoo' 'Kia' 'Force' 'Ambassador' 'Ashok' 'Isuzu' 'Opel' 'Peugeot']

# %%
brand_counts = df["brand"].value_counts()
print(brand_counts)
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df1.isna().sum()
# Out:
# name                    0
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    140
# engine                140
# max_power             134
# seats                 140
# dtype: int64

# %% [markdown]
# Encoding useing Label encoder

# %%
column=['name','fuel','seller_type','transmission','owner','max_power']

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
for col in column:
  df1[col]=encoder.fit_transform(df1[col])
# Out:
# <ipython-input-16-b74f59bb659a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col]=encoder.fit_transform(df1[col])
# <ipython-input-16-b74f59bb659a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col]=encoder.fit_transform(df1[col])
# <ipython-input-16-b74f59bb659a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     1043  2014         450000     145500     1            1             1
# 1     1273  2014         370000     120000     1            1             1
# 2      295  2006         158000     140000     3            1             1
# 3      618  2010         225000     127000     1            1             1
# 4     1080  2007         130000     120000     3            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 4996   713  2010         200000     120000     3            1             1
# 4997   934  2016         700000      70000     1            1             1
# 4998  1569  2002         229999     290000     1            1             1
# 4999   244  2010         300000      74000     3            1             1
# 5000   349  2015         670000     120000     1            1             1
#
# ...

# %%
df1.dtypes
# Out:
# name                    int64
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                    int64
# seller_type             int64
# transmission            int64
# owner                   int64
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power               int64
# seats                 float64
# dtype: object

# %%
df1.corr()
# Out:
#                         name      year  selling_price  km_driven      fuel  \
# name                1.000000 -0.031569      -0.083045   0.093310 -0.104316
# year               -0.031569  1.000000       0.415477  -0.385135 -0.050623
# selling_price      -0.083045  0.415477       1.000000  -0.213739 -0.190435
# km_driven           0.093310 -0.385135      -0.213739   1.000000 -0.241087
# fuel               -0.104316 -0.050623      -0.190435  -0.241087  1.000000
# seller_type         0.101701 -0.144534      -0.354353   0.110211  0.120517
# transmission        0.036661 -0.258362      -0.597813   0.197511 -0.033712
# owner               0.011632 -0.466511      -0.220649   0.269148 -0.039858
# mileage(km/ltr/kg) -0.035799  0.320751      -0.124516  -0.159833 -0.071296
# engine              0.085763  0.023029       0.455592   0.186619 -0.484686
# max_power          -0.155273  0.029661      -0.231281  -0.075602  0.146280
# ...

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df1.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Handling Missing value

# %%
lst=['mileage(km/ltr/kg)','engine','max_power','seats']

# %%
for lsts in lst:
  df1[lsts]=df1[lsts].fillna(df1[lsts].mode()[0])
# Out:
# <ipython-input-22-39aa87d26e34>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[lsts]=df1[lsts].fillna(df1[lsts].mode()[0])
# <ipython-input-22-39aa87d26e34>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[lsts]=df1[lsts].fillna(df1[lsts].mode()[0])

# %%
df1.isna().sum()
# Out:
# name                  0
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             0
# seats                 0
# dtype: int64

# %%
X=df1.drop(['selling_price'],axis=1)

# %%
X
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  \
# 0     1043  2014     145500     1            1             1      0
# 1     1273  2014     120000     1            1             1      2
# 2      295  2006     140000     3            1             1      4
# 3      618  2010     127000     1            1             1      0
# 4     1080  2007     120000     3            1             1      0
# ...    ...   ...        ...   ...          ...           ...    ...
# 4996   713  2010     120000     3            1             1      0
# 4997   934  2016      70000     1            1             1      0
# 4998  1569  2002     290000     1            1             1      0
# 4999   244  2010      74000     3            1             1      2
# 5000   349  2015     120000     1            1             1      0
#
#       mileage(km/ltr/kg)  engine  max_power  seats
# 0                  23.40  1248.0        219    5.0
# ...

# %%
y=df1['selling_price']
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 4996    200000
# 4997    700000
# 4998    229999
# 4999    300000
# 5000    670000
# Name: selling_price, Length: 5001, dtype: int64

# %% [markdown]
# Scaling using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)
X_scaled
# Out:
# array([[0.64224138, 0.83783784, 0.0612429 , ..., 0.20939597, 0.75      ,
#         0.1       ],
#        [0.783867  , 0.83783784, 0.05043533, ..., 0.29328859, 0.04794521,
#         0.1       ],
#        [0.18165025, 0.62162162, 0.05891186, ..., 0.29295302, 0.78082192,
#         0.1       ],
#        ...,
#        [0.966133  , 0.51351351, 0.12248581, ..., 0.6114094 , 0.76369863,
#         0.6       ],
#        [0.15024631, 0.72972973, 0.03093932, ..., 0.58053691, 0.38013699,
#         0.1       ],
#        [0.21490148, 0.86486486, 0.05043533, ..., 0.29328859, 0.97260274,
#         0.3       ]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)

# %%
X_train.shape,y_train.shape
# Out:
# ((3500, 11), (3500,))

# %%
X_test.shape,y_test.shape
# Out:
# ((1501, 11), (1501,))

# %% [markdown]
# Finding the Best regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error,ConfusionMatrixDisplay

# %%
knn=KNeighborsRegressor()
svr=SVR()
lr=LinearRegression()
dt=DecisionTreeRegressor()
rf=RandomForestRegressor(random_state=1)
ada=AdaBoostRegressor(random_state=1)
gb=GradientBoostingRegressor(random_state=1)
xgb=XGBRegressor()

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
models=[knn,svr,dt,rf,ada,xgb,lr]
for model in models:
  print()
  print('*********',model,"*************")
  print()
  model.fit(X_train,y_train)
  y_pred=model.predict(X_test)
  print('r2 score:',r2_score(y_test,y_pred))
  print('mean_absolute_error:',mean_absolute_error(y_test,y_pred))
  print('mean_squared_error:',mean_squared_error(y_test,y_pred))
  print('root_mean_squared_error:',root_mean_squared_error(y_test,y_pred))
# Out:
# ********* KNeighborsRegressor() *************
#
# r2 score: 0.8889444027603545
# mean_absolute_error: 110961.45716189206
# mean_squared_error: 78420108434.33594
# root_mean_squared_error: 280035.90561629046
#
# ********* SVR() *************
#
# r2 score: -0.06426119665699215
# mean_absolute_error: 402641.90321278875
# mean_squared_error: 751510779454.0177
# root_mean_squared_error: 866897.2138921763
#
# ********* DecisionTreeRegressor() *************
#
# r2 score: 0.9493359589215797
# mean_absolute_error: 82879.69768302613
# mean_squared_error: 35775590729.73068
# root_mean_squared_error: 189144.36478449652
#
# ********* RandomForestRegressor(random_state=1) *************
#
# r2 score: 0.9708621547835037
# mean_absolute_error: 67806.36397479808
# mean_squared_error: 20575216722.213264
# root_mean_squared_error: 143440.63832196672
#
# ********* AdaBoostRegressor(random_state=1) *************
#
# r2 score: 0.8012676152108942
# mean_absolute_error: 303439.73576305876
# ...

# %%
import pickle
pickle.dump(rf,open('Random_Forest_model.sav','wb'))

# %%
pickle.dump(scaler,open('scaler_model.sav','wb'))
